# %% [markdown]
# # Part1: Exploratory Data Analysis(EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
sns.set(font_scale=2) 
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('../input/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# How many Survived??

# %%
f, ax = plt.subplots(1,2, figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%', ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel(' ')
sns.countplot('Survived', data=data, ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# ## Analysing The Features

# %% [markdown]
# ### Sex--> Categorical Feature

# %%
data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f, ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue = 'Survived', data=data, ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# 여자가 생존률이 더 높은 모습을 볼 수 있다

# %% [markdown]
# ### Pclass --> Ordinal Feature

# %%
pd.crosstab(data.Pclass, data.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
#         }    #T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow2_col1 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow2_col2 {
#             background-color:  #90c866;
#             color:  #000000;
#         }    #T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow3_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow3_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow3_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936b" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936blevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow0_col0" class="data row0 col0" >80</td>
#                         <td id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow0_col1" class="data row0 col1" >136</td>
#                         <td id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936blevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow1_col0" class="data row1 col0" >97</td>
#                         <td id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow1_col1" class="data row1 col1" >87</td>
#                         <td id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936blevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow2_col0" class="data row2 col0" >372</td>
#                         <td id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow2_col1" class="data row2 col1" >119</td>
#                         <td id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936blevel0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow3_col0" class="data row3 col0" >549</td>
#                         <td id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow3_col1" class="data row3 col1" >342</td>
#                         <td id="T_d34bbd34_ded8_11ea_b6dd_797bca1b936brow3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
f, ax=plt.subplots(1, 2, figsize=(18, 8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'], ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_title('Count')
sns.countplot('Pclass', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %% [markdown]
# 사람들은 돈으로 모든것을 살 수 없다고 말합니다.
# 하지만 가장 높은 등급인 1등급 클래스의 생존률이 더 높은 모습을 보입니다.

# %%
pd.crosstab([data.Sex, data.Survived], data.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_d5815654_ded8_11ea_b6dd_797bca1b936brow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow0_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow1_col0 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow1_col1 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow1_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow1_col3 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow2_col0 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow2_col1 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow2_col2 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow2_col3 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow3_col0 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow3_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow3_col3 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_d5815654_ded8_11ea_b6dd_797bca1b936brow4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_d5815654_ded8_11ea_b6dd_797bca1b936b" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d5815654_ded8_11ea_b6dd_797bca1b936blevel0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_d5815654_ded8_11ea_b6dd_797bca1b936blevel1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow0_col0" class="data row0 col0" >3</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow0_col1" class="data row0 col1" >6</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow0_col2" class="data row0 col2" >72</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_d5815654_ded8_11ea_b6dd_797bca1b936blevel1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow1_col0" class="data row1 col0" >91</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow1_col1" class="data row1 col1" >70</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow1_col2" class="data row1 col2" >72</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_d5815654_ded8_11ea_b6dd_797bca1b936blevel0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_d5815654_ded8_11ea_b6dd_797bca1b936blevel1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow2_col0" class="data row2 col0" >77</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow2_col1" class="data row2 col1" >91</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow2_col2" class="data row2 col2" >300</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_d5815654_ded8_11ea_b6dd_797bca1b936blevel1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow3_col0" class="data row3 col0" >45</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow3_col1" class="data row3 col1" >17</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow3_col2" class="data row3 col2" >47</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_d5815654_ded8_11ea_b6dd_797bca1b936blevel0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_d5815654_ded8_11ea_b6dd_797bca1b936blevel1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow4_col0" class="data row4 col0" >216</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow4_col1" class="data row4 col1" >184</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow4_col2" class="data row4 col2" >491</td>
#                         <td id="T_d5815654_ded8_11ea_b6dd_797bca1b936brow4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=data)
plt.show()

# %% [markdown]
# 위에서 FactorPlt을 사용했다. 그 이유는 범주형 데이터를 잘 구분 할 수 있기 때문이다.

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1, 2, figsize=(18, 8))
sns.violinplot("Pclass", "Age", hue="Survived",data=data, split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))
sns.violinplot("Sex", "Age", hue="Survived", data=data, split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %% [markdown]
# **분석결과**
# 1) Pclass에 따라 어린이의 수가 증가하고 10 세 미만의 행인 (즉, 어린이)의
# 생존율은 Pclass에 관계없이 양호 해 보입니다.
#
# 2) Pclass1의 20-50 세 Passenegers의 생존 가능성은 높고 여성에게 더 좋습니다.
#
# 3) 남성의 경우 연령이 증가함에 따라 생존 확률이 감소합니다.

# %% [markdown]
# 우리는 앞서 Age의 칼럼에 177명의 NaN(결측)값이 있음을 확인했습니다.
# 하지만 임의로 NaN의 값을 채우기엔 연령이 너무 다양합니다.
# 그렇다면 우리는 어떻게 결측값을 채울 수 있을 까요?
# 바로 이름 앞의 Ms, Mss, Mr를 이용하는 것입니다.
# 한국에는 없지만, 외국에는 이런 특징 덕분에 그나마 나이를 예측할 수 있습니다.
# 다시 말해, 더욱 신빙성 있는 데이터로 만들 수 있는 것입니다.

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.')

# %%
data['Initial'].head()
# Out:
# 0      Mr
# 1     Mrs
# 2    Miss
# 3     Mrs
# 4      Mr
# Name: Initial, dtype: object

# %%
pd.crosstab(data.Initial, data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col9 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col10 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col11 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col12 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col13 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col14 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col15 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col16 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col8 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col10 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col11 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col12 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col13 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col14 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col15 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_0270e418_ded9_11ea_b6dd_797bca1b936brow1_col16 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_0270e418_ded9_11ea_b6dd_797bca1b936b" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dr</th>        <th class="col_heading level0 col5" >Jonkheer</th>        <th class="col_heading level0 col6" >Lady</th>        <th class="col_heading level0 col7" >Major</th>        <th class="col_heading level0 col8" >Master</th>        <th class="col_heading level0 col9" >Miss</th>        <th class="col_heading level0 col10" >Mlle</th>        <th class="col_heading level0 col11" >Mme</th>        <th class="col_heading level0 col12" >Mr</th>        <th class="col_heading level0 col13" >Mrs</th>        <th class="col_heading level0 col14" >Ms</th>        <th class="col_heading level0 col15" >Rev</th>        <th class="col_heading level0 col16" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0270e418_ded9_11ea_b6dd_797bca1b936blevel0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col1" class="data row0 col1" >0</td>
#                         <td id="T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col2" class="data row0 col2" >1</td>
#                         <td id="T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col3" class="data row0 col3" >0</td>
#                         <td id="T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col4" class="data row0 col4" >1</td>
#                         <td id="T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col5" class="data row0 col5" >0</td>
#                         <td id="T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col6" class="data row0 col6" >1</td>
#                         <td id="T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col7" class="data row0 col7" >0</td>
#                         <td id="T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col8" class="data row0 col8" >0</td>
#                         <td id="T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col9" class="data row0 col9" >182</td>
#                         <td id="T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col10" class="data row0 col10" >2</td>
#                         <td id="T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col11" class="data row0 col11" >1</td>
#                         <td id="T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col12" class="data row0 col12" >0</td>
#                         <td id="T_0270e418_ded9_11ea_b6dd_797bca1b936brow0_col13" class="data row0 col13" >125</td>
#                         <t

# %% [markdown]
# 그래프를 보니까 대충 Master, Miss, Mr, Mrs가 많이 보이는 군요.
# 여기서는 Other을 추가해서 총 5가지 카테고리로 나눈것으로 보입니다.
# Master은 8세 미만의 사람을 지칭하는 initial이라고 하는 군요.

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
                        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data.groupby('Initial')['Age'].mean() #lets check the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %% [markdown]
# 위의 결과를 보면 각 카테고리 별로 나이가 나오게 됩니다.
# 0~80세의 나이를 무작위로 넣는 것 보다 이렇게 나눠서 이름을 기반으로 넣는 것이 더 나을 것 같습니다.

# %%
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.Age.isnull().any()
# Out:
# False

# %% [markdown]
# null값이 없어진 것을 확인 할 수 있습니다.

# %%
f, ax=plt.subplots(1, 2, figsize=(20, 10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0], bins=20, edgecolor='white', color='red')
ax[0].set_title('Survived=0')
x1=list(range(0, 85, 5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1], color='green', bins=20, edgecolor='black')
ax[1].set_title('Survived=1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %% [markdown]
# 생존율 그래프를 보면 0-5세 사이의 생존율이 높아보입니다.
# 그리고 나이가 높은 사람들이 사망율 보다 생존율이 높은 경향을 보입니다.
# 빈먄에 30대 분들의 사망율이 높은 모습을 볼 수 있습니다.

# %%
sns.factorplot('Pclass', 'Survived', col='Initial', data=data)
plt.show()

# %% [markdown]
# 역시 여성들과 아이들의 생존율이 더 높은 경향을 확인 할 수 있습니다.

# %% [markdown]
# ### Embarked--> Categorical Value

# %%
pd.crosstab([data.Embarked, data.Pclass], [data.Sex, data.Survived], 
            margins=True).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow0_col0 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow0_col1 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow0_col2 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow0_col3 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow0_col4 {
#             background-color:  #e5eff9;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow1_col1 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow1_col2 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow1_col3 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow1_col4 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow2_col0 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow2_col1 {
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow2_col2 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow2_col3 {
#             background-color:  #e5eff9;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow2_col4 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow3_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow3_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow3_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow3_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow3_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow4_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow4_col1 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow4_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow4_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow4_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow5_col0 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow5_col1 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow5_col2 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow5_col3 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow5_col4 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow6_col0 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow6_col1 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow6_col2 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow6_col3 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow6_col4 {
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow7_col0 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow7_col1 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow7_col2 {
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow7_col3 {
#             background-color:  #dce9f6;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow7_col4 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow8_col0 {
#             background-color:  #3484bf;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow8_col1 {
#             background-color:  #dce9f6;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow8_col2 {
#             background-color:  #6dafd7;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow8_col3 {
#             background-color:  #b3d3e8;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow8_col4 {
#             background-color:  #95c5df;
#             color:  #000000;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow9_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow9_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow9_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow9_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0aef2ffa_ded9_11ea_b6dd_797bca1b936brow9_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_0aef2ffa_ded9_11ea_b6dd_797bca1b936b" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Sex</th>        <th class="col_heading level0 col0" colspan=2>female</th>        <th class="col_heading level0 col2" colspan=2>male</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Survived</th>        <th class="col_heading level1 col0" >0</th>        <th class="col_heading level1 col1" >1</th>        <th class="col_heading level1 col2" >0</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" ></th>    </tr>    <tr>        <th class="index_name level0" >Embarked</th>        <th class="index_name level1" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0aef2ffa_ded9_11ea_b6dd_797bca1b936blevel0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#                         <th id="T_0aef2ffa_ded9_11ea_b6dd_797bca1b936blevel1_row0" class="row_heading level1 row0" >1</th>
#                         <td id="T_0aef2ffa_ded9_11ea_b

# %% [markdown]
# 위의 그래프는 [탑승구, 객실등급]을 행으로 [성별, 생존율]을 열로 두고 관계를 보여주는 그래프이다.
# 색의 변화를 통해 칼럼 사이의 관계를 눈으로 확인 할 수 있다.

# %%
sns.factorplot('Embarked', 'Survived', data=data)
fig=plt.gcf()
fig.set_size_inches(7, 4)
plt.show()

# %% [markdown]
# C 항구의 생존률이 굉장히 높아보입니다.
# 이유가 뭘까요?

# %%
f, ax=plt.subplots(2,2, figsize=(20, 15))
sns.countplot('Embarked', data=data, ax=ax[0,0])
ax[0,0].set_title('No. of Passengers Boarded')
sns.countplot('Embarked', hue='Sex', data=data, ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked', hue='Survived', data=data, ax=ax[1, 0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %% [markdown]
# 탑승구에 따라 생존률이 변하는 모습이 궁금해서 4개의 그래프를 그렸습니다.
# 1. 탑승구당 사람의 수
# 2. 탑승구의 남녀 분포
# 3. 탑승구당 생존 확률
# 4. 탑승구의 Pclass 분포
#
# 우선 S탑승구에 사람이 가장 많습니다. 그리고 사망률 또한 엄청 높게 나옵니다.
# S탑승구에는 남성이 많고 third 클래스가 압도적으로 많기 때문에
# 사망률이 더 많은 것 같네요.
# 반대로 C탑승구에는 first 클래스가 가장 많습니다.
# 그래서 생존률이 더 높을 수 밖에 없는 것 같습니다.
# 그리고 Q탑승구에는 third 클래스가 95%정도 있는 것을 확인했습니다.

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', col='Embarked', data=data)
plt.show()

# %% [markdown]
# factorplot으로 보니 더욱 명확해지는 것 같습니다.
# 여기서 seaborn의 그래프 사용법을 살짝 설명하겠습니다.
# 'Pclass'와 'Survived'는 각각 x축, y축에 사용됩니다.
# **hue** 파라미터로 그래프의 개수가 결정되는 것 같습니다.
# 범주(legend)로 나타나지고 오른쪽에 정리되어있네요.
# **col**파라미터는 여러개의 박스를 생성합니다.
#
# 그래프를 해석해보면 남자의 생존률이 대부분 낮음을 확인할 수 있습니다.
# 1. Pclass와 상관없이 1, 2 클래스 여자의 생존률은 거의 1에 가깝습니다.
# 2. S 탑승구에는 여자, 남자 모두 다른 탑승구에 비해 생존률이 낮아서 전체적인 생존률이 낮아보입니다.
# 3. Q 탑승구에서는 남자의 생존률이 희박합니다. 그 이유는 Pclass 3이기 때문입니다.

# %% [markdown]
# ### Filling Embarked NaN

# %% [markdown]
# Port S에 사람이 가장 많음으로 NaN을 S로 바꾸겠습니다.

# %%
data['Embarked'].fillna('S', inplace=True)

# %%
data.Embarked.isnull().any()
# Out:
# False

# %% [markdown]
# ### SibSip-->Discrete Feature

# %% [markdown]
# 이 feature은 그 사람이 가족이 있는지 아니면 혼자인지 나타냅니다.
#
# - Sibiling = 형, 누나, 동생
# - Spouse = 남편, 아내

# %%
pd.crosstab([data.SibSp], data.Survived).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_0f365354_ded9_11ea_b6dd_797bca1b936brow0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0f365354_ded9_11ea_b6dd_797bca1b936brow0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0f365354_ded9_11ea_b6dd_797bca1b936brow1_col0 {
#             background-color:  #caddf0;
#             color:  #000000;
#         }    #T_0f365354_ded9_11ea_b6dd_797bca1b936brow1_col1 {
#             background-color:  #60a7d2;
#             color:  #000000;
#         }    #T_0f365354_ded9_11ea_b6dd_797bca1b936brow2_col0 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_0f365354_ded9_11ea_b6dd_797bca1b936brow2_col1 {
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }    #T_0f365354_ded9_11ea_b6dd_797bca1b936brow3_col0 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_0f365354_ded9_11ea_b6dd_797bca1b936brow3_col1 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_0f365354_ded9_11ea_b6dd_797bca1b936brow4_col0 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_0f365354_ded9_11ea_b6dd_797bca1b936brow4_col1 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_0f365354_ded9_11ea_b6dd_797bca1b936brow5_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0f365354_ded9_11ea_b6dd_797bca1b936brow5_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0f365354_ded9_11ea_b6dd_797bca1b936brow6_col0 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_0f365354_ded9_11ea_b6dd_797bca1b936brow6_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_0f365354_ded9_11ea_b6dd_797bca1b936b" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0f365354_ded9_11ea_b6dd_797bca1b936blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0f365354_ded9_11ea_b6dd_797bca1b936brow0_col0" class="data row0 col0" >398</td>
#                         <td id="T_0f365354_ded9_11ea_b6dd_797bca1b936brow0_col1" class="data row0 col1" >210</td>
#             </tr>
#             <tr>
#                         <th id="T_0f365354_ded9_11ea_b6dd_797bca1b936blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0f365354_ded9_11ea_b6dd_797bca1b936brow1_col0" class="data row1 col0" >97</td>
#                         <td id="T_0f365354_ded9_11ea_b6dd_797bca1b936brow1_col1" class="data row1 col1" >112</td>
#             </tr>
#             <tr>
#                         <th id="T_0f365354_ded9_11ea_b6dd_797bca1b936blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0f365354_ded9_11ea_b6dd_797bca1b936brow2_col0" class="data row2 col0" >15</td>
#                         <td id="T_0f365354_ded9_11ea_b6dd_797bca1b936brow2_col1" class="data row2 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_0f365354_ded9_11ea_b6dd_797bca1b936blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0f365354_ded9_11ea_b6dd_797bca1b936brow3_col0" class="data row3 col0" >12</td>
#                         <td id="T_0f365354_ded9_11ea_b6dd_797bca1b936brow3_col1" class="data row3 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_0f365354_ded9_11ea_b6dd_797bca1b936blevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0f365354_ded9_11ea_b6dd_797bca1b936brow4_col0" class="data row4 col0" >15</td>
#                         <td id="T_0f365354_ded9_11ea_b6dd_797bca1b936brow4_col1" class="data row4 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_0f365354_ded9_11ea_b6dd_797bca1b936blevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0f365354_ded9_11ea_b6dd_797bca1b936brow5_col0" class="data row5 col0" >5</td>
#                         <td id="T_0f365354_ded9_11ea_b6dd_797bca1b936brow5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_0f365354_ded9_11ea_b6dd_797bca1b936blevel0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_0f365354_ded9_11ea_b6dd_797bca1b936brow6_col0" class="data row6 col0" >7</td>
#                         <td id="T_0f365354_ded9_11ea_b6dd_797bca1b936brow6_col1" class="data row6 col1" >0</td>
#             </tr>
#     </tbody></table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived',data=data,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
sns.factorplot('SibSp','Survived',data=data,ax=ax[1])
ax[1].set_title('SibSp vs Survived')
plt.close(2)
plt.show()

# %% [markdown]
# 혼자만 있을 때는 생존률이 대략 34.5%입니다.
# 그리고 가족이 1, 2명 더 있으면 생존률이 대략 늘어나지만,
# 3, 4 명이 되면 더 줄어들게 됩니다.
# 그 이유는 아마 서로 구하다가 사고를 당하는 것 같습니다.
# 근데 5, 8명 생존률이 0입니다. 왜 그럴까요?

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow1_col0 {
#             background-color:  #7bbd66;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow1_col1 {
#             background-color:  #8ac466;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow1_col2 {
#             background-color:  #c6e266;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow2_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow2_col1 {
#             background-color:  #eef666;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow2_col2 {
#             background-color:  #f8fc66;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow3_col0 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow3_col1 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow3_col2 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow4_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow4_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow4_col2 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow5_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow6_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_11177a0e_ded9_11ea_b6dd_797bca1b936brow6_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }</style><table id="T_11177a0e_ded9_11ea_b6dd_797bca1b936b" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_11177a0e_ded9_11ea_b6dd_797bca1b936blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow0_col0" class="data row0 col0" >137</td>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow0_col1" class="data row0 col1" >120</td>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow0_col2" class="data row0 col2" >351</td>
#             </tr>
#             <tr>
#                         <th id="T_11177a0e_ded9_11ea_b6dd_797bca1b936blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow1_col0" class="data row1 col0" >71</td>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow1_col1" class="data row1 col1" >55</td>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow1_col2" class="data row1 col2" >83</td>
#             </tr>
#             <tr>
#                         <th id="T_11177a0e_ded9_11ea_b6dd_797bca1b936blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow2_col0" class="data row2 col0" >5</td>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow2_col1" class="data row2 col1" >8</td>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow2_col2" class="data row2 col2" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_11177a0e_ded9_11ea_b6dd_797bca1b936blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow3_col0" class="data row3 col0" >3</td>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow3_col1" class="data row3 col1" >1</td>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow3_col2" class="data row3 col2" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_11177a0e_ded9_11ea_b6dd_797bca1b936blevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow4_col0" class="data row4 col0" >0</td>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow4_col1" class="data row4 col1" >0</td>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow4_col2" class="data row4 col2" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_11177a0e_ded9_11ea_b6dd_797bca1b936blevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow5_col0" class="data row5 col0" >0</td>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow5_col1" class="data row5 col1" >0</td>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_11177a0e_ded9_11ea_b6dd_797bca1b936blevel0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow6_col0" class="data row6 col0" >0</td>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow6_col1" class="data row6 col1" >0</td>
#                         <td id="T_11177a0e_ded9_11ea_b6dd_797bca1b936brow6_col2" class="data row6 col2" >7</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# 그 이유는 Pclass에서 찾을 수 있습니다.
# 가족이 4, 5, 8명은 third 클래스만 있습니다.
# 앞서 우리는 third 클래스의 생존률이 처참하게 낮았던 모습을 보았습니다.
# 그러니 당연히 생존율이 낮을 수 밖에 없습니다.
# 즉, 가족수의 영향보단 클래스의 영향이 커보입니다.

# %% [markdown]
# ### Parch

# %% [markdown]
# Parch는 함께 탑승한 부모, 자녀 수의 총합입니다.
# 형제, 아내와 다른 결과를 보이는지 확인해봅시다!

# %%
pd.crosstab(data.Parch, data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow1_col0 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow1_col1 {
#             background-color:  #c2e066;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow1_col2 {
#             background-color:  #dbed66;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow2_col0 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow2_col1 {
#             background-color:  #e1f066;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow2_col2 {
#             background-color:  #e3f166;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow3_col1 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow3_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow4_col0 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow4_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow4_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow5_col2 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow6_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow6_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936b" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >Parch</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow0_col0" class="data row0 col0" >163</td>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow0_col1" class="data row0 col1" >134</td>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow0_col2" class="data row0 col2" >381</td>
#             </tr>
#             <tr>
#                         <th id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow1_col0" class="data row1 col0" >31</td>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow1_col1" class="data row1 col1" >32</td>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow1_col2" class="data row1 col2" >55</td>
#             </tr>
#             <tr>
#                         <th id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow2_col0" class="data row2 col0" >21</td>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow2_col1" class="data row2 col1" >16</td>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow2_col2" class="data row2 col2" >43</td>
#             </tr>
#             <tr>
#                         <th id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow3_col0" class="data row3 col0" >0</td>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow3_col1" class="data row3 col1" >2</td>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow3_col2" class="data row3 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936blevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow4_col0" class="data row4 col0" >1</td>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow4_col1" class="data row4 col1" >0</td>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow4_col2" class="data row4 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936blevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow5_col0" class="data row5 col0" >0</td>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow5_col1" class="data row5 col1" >0</td>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936blevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow6_col0" class="data row6 col0" >0</td>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow6_col1" class="data row6 col1" >0</td>
#                         <td id="T_9b1f21c2_defa_11ea_b6dd_797bca1b936brow6_col2" class="data row6 col2" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# 그래프를 보면 가족수가 많을 수록 Pclass 3이 더 많이 보이는 군요.

# %%
f, ax= plt.subplots(1, 2, figsize=(20,8))
sns.barplot('Parch', 'Survived', data=data, ax=ax[0])
ax[0].set_title("Parch vs Survived")
sns.factorplot('Parch', 'Survived', data=data, ax=ax[1])
ax[1].set_title('Parch vs Survived')
# Out:
# Text(0.5, 1.0, 'Parch vs Survived')

# %% [markdown]
# 부모 or 자녀가 1-3명 일 때 가장 생존율이 높습니다.
# 혼자 있을 때는 생존률이 50%도 안되는 걸로 보아 위험한 것 같습니다.
# 하지만 4명 이상이 되면 생존률이 급격히 낮아집니다.
# 이것도 Pclass의 영향인 것 같습니다.

# %% [markdown]
# ### Fare--> Continous Feature

# %% [markdown]
# 탑승 요금에 따라 생존률이 어떻게 달라지는 지 알아보겠습니다.

# %%
print('Highest Fare was:',data['Fare'].max())
print('Lowest Fare was:',data['Fare'].min())
print('Average Fare was:',data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.2042079685746

# %% [markdown]
# 최소 요금은 0.0입니다.
# 공짜로 타이타닉이라는 호화로운 여객선에 탑승한 셈입니다!

# %%
f, ax = plt.subplots(1, 3, figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare, ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare, ax=ax[1])
ax[1].set_title('Fare in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# 그래프를 보니까 분포가 너무 커보입니다.
# 그리고 이런 분포는 표준이 감소함에 따라 줄어들게 됩니다.
# 연속적인 값은 Binning(구간으로 나누어 범주화)로 처리할 수 있습니다.

# %% [markdown]
# **전체적으로 feature을 정리해봅시다.**
# 1. Sex: 남자보다 여자의 생존 확률이 더 커보입니다.
# 2. Pclass: Class의 숫자가 낮아질수록 (1->2->3) 생존률이 점점 낮아집니다.
# 3. Age: 5-10살 정도의 생존률이 가장 높고 15-35살은 사망률이 많습니다.
# 4. Embarked: C 탑승구의 생존률이 가장 높습니다. S 탑승구에는 3rd class가 많은 만큼 사망률도 높습니다.
# 5. Parch+SibSp: 1-2명의 가족과 같이 탑승 했을 때 가장 생존률이 높은 경향을 보입니다.

# %% [markdown]
# ### Correlation Between The Features

# %%
sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# ### Interpreting The Heatmap
